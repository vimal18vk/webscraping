# %%
import requests

from bs4 import BeautifulSoup

r = requests.get("https://property.sulekha.com/commercial-office-space-for-rent/guindy-chennai")
c = r.content
c
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n    \r\n\r\n<title> 71 Office Space for Rent in Guindy, Chennai, Rental IT Parks | Sulekha Chennai</title>\r\n<meta name="description" content=" Find  Commercial Office Spaces for Rent in Guindy, Chennai only on Sulekha. Take advantage of filters and find office spaces based on Furnished, Semi Furnished, Real Owner, Original Photos &amp; much more." />\r\n<meta name="keywords" content="commercial office space in guindy, office space for rent in guindy, office space in guindy for rent" />\r\n<link rel="canonical" href="https://property.sulekha.com/commercial-office-space-for-rent/guindy-chennai" />\r\n<meta name="distribution" content="global" />\r\n<meta http-equiv="content-language" content="en-gb" />\r\n\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge" />\r\n\r\n<meta name="copyright" content="Sulekha.com New Media Pvt. Limited" />\r\n\r\n<meta property="og:title" content=" 71 Office Space for Rent in Guindy, Chennai, Rental IT Parks | Sulekha Chennai" />\r\n<meta property="og:description" content="Find  Commercial Office Spaces for Rent in Guindy, Chennai only on Sulekha. Take advantage of filters and find office spaces based on Furnished, Semi Furnished, Real Owner, Original Photos &amp; much more." />\r\n<meta property="og:url" content="https://property.sulekha.com/commercial-office-space-for-rent/guindy-chennai" />\r\n<meta property="og:type" content="website" />\r\n<meta property="og:sitename" content="Sulekha.com - Local Services" />\r\n<meta property="og:locale" content="en_GB">\r\n<meta property="og:image" content="https://sulcdn.azureedge.net/content/images/sulekha-logo-fb.png" />\r\n\r\n<link rel="alternate" href="" />\r\n<meta name="format-detection" content="telephone=yes" />\r\n<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5" />\r\n<link rel="dns-prefetch" href="//www.googletagmanager.com/">\r\n<link rel="dns-prefetch" href="//lscdn.azureedge.net/">\r\n<link rel="dns-prefetch" href="//bingads.microsoft.com/">\r\n<link rel="dns-prefetch" href="//www.google-analytics.com/">\r\n<link rel="dns-prefetch" href="//analytics.google.com/">\r\n<link rel="dns-prefetch" href="//sulcdn.azureedge.net/">\r\n<link rel="dns-prefetch" href="//sulekha.azureedge.net/">\r\n<link rel="dns-prefetch" href="//connect.facebook.net/">\r\n<link rel="dns-prefetch" href="//www.facebook.com/">\r\n\r\n<link rel="shortcut icon" href="//sulcdn.azureedge.net/content/images/favicon.ico" />\r\n\r\n<link rel="preconnect" href="https://sulcdn.azureedge.net/" crossorigin>\r\n\r\n<script type="text/javascript">document.domain = "sulekha.com";</script>\r\n<!-- TODO - use the model.bc variable and load the breadcrumb schema as given in https://developers.google.com/search/docs/data-types/breadcrumb#json-ld_1 -->\r\n\r\n\r\n<style>\r\n    html{-webkit-text-size-adjust:100%;box-sizing:border-box;scroll-behavior:smooth;-webkit-tap-highlight-color:transparent}*,:after,:before{box-sizing:inherit}body{margin:0;color:var(--gray-900);background-color:var(--gray-100);padding-top:5rem}a{background-color:transparent;outline:0}ul{padding:0;margin:0}b,strong{font-weight:bolder}img{border-style:none}p{line-height:2.2rem;font-size:1.4rem;color:var(--gray-900)}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible;outline:0}button,select{text-transform:none;outline:0;border:0}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}input[type=search]::-webkit-search-cancel-button,input[type=search]::-webkit-search-decoration,input[type=search]::-webkit-search-results-button,input[type=search]::-webkit-search-results-decoration{-webkit-appearance:none}:root{--blue-50:#FAFDFF;--blue-100:#F3F9FF;--blue-200:#E3EFFF;--blue-300:#B7D4FF;--blue-400:#81B0FF;--blue-500:#5090FF;--blue-600:#0066FF;--blue-700:#004EAF;--blu ...

# %%
soup=BeautifulSoup(c,"html.parser")

# %%
print(soup.prettify())

# %%
all=soup.find_all("li",{"class":"list-item"})
all

# %%
len(all)

# %%
all[0]

# %%
all[0].find_all("h3") #price is defined by using tag and dimension array value

# %%
all[0].find_all("h3")[0].text # to get only text

# %%
for item in all:   #to display all price value in the website
    print(item.find_all("h3")[0].text)

# %%
l=[]
for item in all:   #to display all price value in the website
    d={}
    d["Sqft area"]=item.find_all("h3")[0].text.replace("Office Space for Rent in Guindy","")
    d["Location"]=item.find_all("span",{"class":"location f-icon"})[0].text.replace(" ","")
    d["month_rent"]=item.find_all("i",{"class":"f-icon"})[0].text.replace(" ",""),"/month"
    d["deposit"]=item.find_all("span",{"class":"deposit"})[0].text.replace("Deposit:","").replace(" ","")
    try:
        d["building name"]=item.find_all("span",{"class":"buztitle"})[0].text.replace(" ","")
    except:
        d["building name"]=None
    
    
    #print(item.find_all("span",{"class":"feature primary"})[0].text.replace(" ","") )
    #print(item.find_all("div",{"class":"locality"})[0].text.replace(" ","").replace("ViewMap","") )
    d["broker name"]=item.find_all("span",{"class":"bsnsname"})[0].text.replace(" ","").replace("Broker:","") 
    d["posted on"]=item.find_all("span",{"class":"postdate f-icon"})[0].text.replace(" ","") 
    '''try:
         d["requirements"]=item.find_all("div",{"class":"spec icon primary"})[0].text.replace(" ","")
    except:
         d["requirements"]=None
         '''
   
    l.append(d)

# %%
l

# %%
len(l)

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df

# %%
df.to_csv("sulekha.csv")
